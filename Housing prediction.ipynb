# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\USER\Desktop\DATA ANALYTICA FILE\Python\Housing data.csv")

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
x = df[['area', 'bedrooms', 'bathrooms', 'stories', 'mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'parking', 'prefarea']]

# %%
x
# Out:
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    7420         4          2        3      yes        no       no
# 1    8960         4          4        4      yes        no       no
# 2    9960         3          2        2      yes        no      yes
# 3    7500         4          2        2      yes        no      yes
# 4    7420         4          1        2      yes       yes      yes
# ..    ...       ...        ...      ...      ...       ...      ...
# 540  3000         2          1        1      yes        no      yes
# 541  2400         3          1        1       no        no       no
# 542  3620         2          1        1      yes        no       no
# 543  2910         3          1        1       no        no       no
# 544  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea
# 0                no             yes        2      yes
# ...

# %%
x= pd.get_dummies(x, drop_first = True, dtype = 'int')

# %%
x
# Out:
#      area  bedrooms  bathrooms  stories  parking  mainroad_yes  guestroom_yes  \
# 0    7420         4          2        3        2             1              0
# 1    8960         4          4        4        3             1              0
# 2    9960         3          2        2        2             1              0
# 3    7500         4          2        2        3             1              0
# 4    7420         4          1        2        2             1              1
# ..    ...       ...        ...      ...      ...           ...            ...
# 540  3000         2          1        1        2             1              0
# 541  2400         3          1        1        0             0              0
# 542  3620         2          1        1        0             1              0
# 543  2910         3          1        1        0             0              0
# 544  3850         3          1        2        0             1              0
#
# ...

# %%
y = df.price

# %%
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, random_state = 355, test_size = 0.2)

# %%
X_train
# Out:
#      area  bedrooms  bathrooms  stories  parking  mainroad_yes  guestroom_yes  \
# 495  4000         3          1        2        1             1              0
# 300  4079         3          1        3        0             1              0
# 328  4500         3          2        2        0             0              0
# 499  3630         3          3        2        0             0              1
# 294  4000         4          2        2        0             0              0
# ..    ...       ...        ...      ...      ...           ...            ...
# 255  5885         2          1        1        1             1              0
# 51   6325         3          1        4        1             1              0
# 291  2953         3          1        2        0             1              0
# 501  2430         3          1        1        0             0              0
# 346  2176         2          1        2        0             1              1
#
# ...

# %%
X_test
# Out:
#       area  bedrooms  bathrooms  stories  parking  mainroad_yes  \
# 442   2684         2          1        1        1             1
# 224  10240         2          1        1        2             1
# 7    16200         5          3        2        0             1
# 289   5850         2          1        1        2             1
# 457   3000         3          1        1        0             0
# ..     ...       ...        ...      ...      ...           ...
# 22    8050         3          1        1        1             1
# 242   3640         3          1        2        0             1
# 316   5900         4          2        2        1             0
# 459   3500         2          1        1        0             1
# 533   2400         3          1        2        0             1
#
#      guestroom_yes  basement_yes  hotwaterheating_yes  airconditioning_yes  \
# 442              0             0                    0                    1
# ...

# %%
y_train
# Out:
# 495    2730000
# 300    4200000
# 328    3990000
# 499    2660000
# 294    4200000
#         ...
# 255    4480000
# 51     7420000
# 291    4200000
# 501    2660000
# 346    3850000
# Name: price, Length: 436, dtype: int64

# %%
y_test
# Out:
# 442     3220000
# 224     4760000
# 7      10150000
# 289     4200000
# 457     3115000
#          ...
# 22      8645000
# 242     4550000
# 316     4060000
# 459     3115000
# 533     2100000
# Name: price, Length: 109, dtype: int64

# %%
LR = LinearRegression()

# %%
LR.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
LR.score(X_test, y_test)
# Out:
# 0.7016513240576336

# %%
y_pred = LR.predict(X_test)

# %%
y_pred
# Out:
# array([3940461.4822403 , 6721922.37633785, 8329592.59251729,
#        4689762.57932782, 3308453.78404656, 4756720.57575523,
#        3759946.99341758, 7210451.22289276, 6212935.8892731 ,
#        8342436.83794688, 3684490.19234679, 6174322.79580285,
#        6501126.55894381, 3152951.24690586, 6791330.0404086 ,
#        6547466.74659475, 7649861.80199461, 2577952.48979219,
#        5635103.79846025, 3050148.70548477, 5975712.87816169,
#        3621342.42271308, 4098061.14500439, 2315977.212157  ,
#        5508696.16618957, 4446411.66844717, 3048827.18515508,
#        5437937.16864599, 5210015.87461997, 4533907.17596453,
#        2933157.69499982, 3479117.68853264, 3459124.10604813,
#        4383155.4334956 , 4907135.36837405, 4128288.33538727,
#        5135844.87099461, 3470691.05506365, 7227752.90770553,
#        3025693.28712402, 7515304.20032424, 3766677.00666676,
#        3686150.9804444 , 2197994.33219863, 2663647.78293807,
# ...

# %%
rmse = root_mean_squared_error(y_test, y_pred)

# %%
rmse
# Out:
# 1086358.747689041

# %%
import pickle

# %%
#SAVE THE MODEL
with open('model.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
from IPython.display import FileLink
FileLink('model.pkl')
# Out:
# C:\Users\USER\model.pkl
